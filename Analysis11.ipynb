# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import pandas
jan= pandas.read_csv('Jan Month.csv')
janTop= pandas.read_csv('Top50 Jan.csv')
janBottom= pandas.read_csv('Bottom50 Jan.csv')
print(jan)
# Out:
#      Cloaking                         Campaign          Client Account Name  \
# 0       58567               Vueling_IT_Abishek    Tradedoubler        Pavni
# 1       92977                  Massimodutti US         Rakuten        Rahul
# 2       11058  Born2be_PL_Tradedoubler_Abishek    Tradedoubler        Pavni
# 3       14911                      Whitefox US         Rakuten       Dinesh
# 4       59594               Pizzahut_TW_Shashi  Affiliates one         Aman
# ..        ...                              ...             ...          ...
# 470     19748                      AllBirds US      Flexoffers         Aman
# 471     42854                   New Balance US          Impact    CDPraveen
# 472     53350                 The Body Shop UK          Adspay         Aman
# 473     89538               Rebecca Minkoff US       Pepperjam        Rahul
# 474     84215                   SuzanneGrae AU    PartnerBoost      Yasmine
#
# ...

# %%
janTop.head(5)
# Out:
#    Cloaking        Campaign        Client Account Name Platform      AM  \
# 0     31232  ToolStation UK       Rakuten       Dinesh  Adwords  Hardik
# 1     90684  Que hoteles ES     Propelbon         Amey  Adwords  Pratap
# 2     89528        Renee PL  Tradedoubler        Pavni  Adwords  Shashi
# 3     99740        Three UK     Yield Kit      Yasmine  Adwords    Amit
# 4     63540   Fleet Feet US       Rakuten        Rahul  Adwords  Pratap
#
#           CM    Traffic  Paid Traffic  Brand Search  ... Cloaking Clicks  \
# 0       Aman        NaN           NaN           NaN  ...               0
# 1  Siddharth   200000.0       12000.0       41000.0  ...            4836
# 2       Aman        NaN           NaN           NaN  ...               0
# 3       Aman        NaN           NaN           NaN  ...               0
# 4       Aman  2000000.0      600000.0      210000.0  ...           46494
#
#   Google Clicks  Amount Spend     Revenue  Conversion NEW/OLD         EPC  \
# ...

# %%
jan.nlargest(5, ['Revenue'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 jan.nlargest(5, ['Revenue'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:7335, in DataFrame.nlargest(self, n, columns, keep)
#    7230 def nlargest(self, n: int, columns: IndexLabel, keep: str = "first") -> DataFrame:
#    7231     """
#    7232     Return the first `n` rows ordered by `columns` in descending order.
#    7233
#    (...)
#    7333     Brunei      434000    12128      BN
#    7334     """
# -> 7335     return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:1273, in SelectN.nlargest(self)
#    1271 @final
#    1272 def nlargest(self):
# -> 1273     return self.compute("nlargest")
#
# ...

# %%
# Extract the date and close price columns
Campaign = janTop['Campaign']
Revenue = janTop['Revenue']

# Create a line plot
plt.plot(Revenue,Campaign)

# Show the plot
plt.show()

# %%
import pandas
Top= pandas.read_csv('Top 50.csv')

# %%
Top.head()
# Out:
#      Date  ToolStation UK  Que hoteles ES  Renee PL  Three UK  Fleet Feet US  \
# 0   Jan-3               0           13280     23738     12479        27805.0
# 1   Jan-7               0           93396     49249     39278        69480.0
# 2  Jan-10            3074          143173     47725     40233        40788.0
# 3  Jan-14           47500          150082     77730     53427        75665.0
# 4  Jan-15           22100           40954     26987     26342        11987.0
#
#    Manomano FR  Affordable Mobiles UK Brands  On the Beach UK  \
# 0      63123.0                           0.0          41573.0
# 1      68671.0                       11093.0          94636.0
# 2     119151.0                        3707.0          33465.0
# 3      56756.0                       40626.0          27784.0
# 4      25840.0                        3679.0           9893.0
#
#    Affordable Mobiles UK  ...  Vueling_IT_Abishek  Currys UK  Kits CA  \
# ...

# %%
# Extract the date and close price columns
Date = Top['Date']
ToolStation = Top['ToolStation UK']

# Create a line plot
plt.plot(Date,ToolStation)
plt.plot(ToolStation, marker = 'o',color = 'b',linewidth = '1.5')

# Show the plot
plt.show()
